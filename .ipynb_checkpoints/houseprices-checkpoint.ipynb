# %%
# %matplotlib inline


import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import os

np.random.seed(10)

# %%
os.chdir("/Users/NNK/Documents/project/kaggle/houseprices")

htrain = pd.read_csv('train.csv')
htest = pd.read_csv('test.csv')

htrain.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#Basic transformations

#
htrain = htrain.drop('Id', axis=1)

###
#Create ranges for year variables 
###
htrain['YrsOld'] = 2017 - htrain['YearBuilt']
htrain['YrsRM'] = 2017 - htrain['YearRemodAdd']
htrain['YrsSS'] = 2017 - htrain['YrSold']

# Drop year variables
htrain = htrain.drop(['YearBuilt','YearRemodAdd','YrSold'],axis=1)

htrain.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ...  Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub    Inside  ...    NaN         NaN       0      2
# 1         Lvl    AllPub       FR2  ...    NaN         NaN       0      5
# 2         Lvl    AllPub    Inside  ...    NaN         NaN       0      9
# 3         Lvl    AllPub    Corner  ...    NaN         NaN       0      2
# 4         Lvl    AllPub       FR2  ...    NaN         NaN       0     12
#
#   SaleType SaleCondition  SalePrice  YrsOld YrsRM YrsSS
# 0       WD        Normal     208500      14    14     9
# 1       WD        Normal     181500      41    41    10
# 2       WD        Normal     223500      16    15     9
# 3       WD       Abnorml     140000     102    47    11
# 4       WD        Normal     250000      17    17     9
#
# [5 rows x 80 columns]

# %%
#%%
# Clean data and convert to all numeric.
#-------------------------

# Fill NAs with 0 first step
htrain = htrain.fillna(value=0)

# Seperate numerical and non-numerical columns into dataframes
numht = htrain.select_dtypes(include = ['float64','int64'])
nonht = htrain.select_dtypes(exclude = ['float64','int64'])

#Create empty df and pass all columns from non-numeric df 
# converted to categorical
non2 = pd.DataFrame()
for column in nonht:
    non2[column] = pd.Categorical(nonht[column])

#Create another empty df and pass all columns from categorical df
# converted to codes    
nonC = pd.DataFrame()
for column in non2:
    nonC[column] = non2[column].cat.codes
    
#Combine the native numerical and newly converted dataframes
trNum = pd.concat([numht,nonC], axis=1)

trNum.head(5)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  \
# 0          60         65.0     8450            7            5       196.0
# 1          20         80.0     9600            6            8         0.0
# 2          60         68.0    11250            7            5       162.0
# 3          70         60.0     9550            7            5         0.0
# 4          60         84.0    14260            8            5       350.0
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF      ...        GarageType  \
# 0         706           0        150          856      ...                 2
# 1         978           0        284         1262      ...                 2
# 2         486           0        434          920      ...                 2
# 3         216           0        540          756      ...                 6
# 4         655           0        490         1145      ...                 2
#
#    GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 0             2           5           5           2       0      0
# 1             2           5           5           2       0      0
# 2             2           5           5           2       0      0
# 3             3           5           5           2       0      0
# 4             2           5           5           2       0      0
#
#    MiscFeature  SaleType  SaleCondition
# 0            0         8              4
# 1            0         8              4
# 2            0         8              4
# 3            0         8              0
# 4            0         8              4
#
# [5 rows x 80 columns]

# %%
#Create normalized dataframe
trNum_norm = (trNum - trNum.mean()) / (trNum.max() - trNum.min())

trNum_norm.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  MasVnrArea  \
# 0    0.018251     0.023568 -0.009661     0.100076    -0.071918    0.058052
# 1   -0.217043     0.071491 -0.004285    -0.011035     0.303082   -0.064448
# 2    0.018251     0.033152  0.003427     0.100076    -0.071918    0.036802
# 3    0.077075     0.007593 -0.004519     0.100076    -0.071918   -0.064448
# 4    0.018251     0.084271  0.017496     0.211187    -0.071918    0.154302
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF      ...        GarageType  \
# 0    0.046485    -0.03158  -0.178613    -0.032967      ...         -0.182877
# 1    0.094678    -0.03158  -0.121250     0.033481      ...         -0.182877
# 2    0.007505    -0.03158  -0.057038    -0.022493      ...         -0.182877
# 3   -0.040333    -0.03158  -0.011661    -0.049334      ...          0.483790
# 4    0.037449    -0.03158  -0.033065     0.014332      ...         -0.182877
#
#    GarageFinish  GarageQual  GarageCond  PavedDrive    PoolQC     Fence  \
# 0     -0.020776    0.081096    0.074384    0.071918 -0.003425 -0.116781
# 1     -0.020776    0.081096    0.074384    0.071918 -0.003425 -0.116781
# 2     -0.020776    0.081096    0.074384    0.071918 -0.003425 -0.116781
# 3      0.312557    0.081096    0.074384    0.071918 -0.003425 -0.116781
# 4     -0.020776    0.081096    0.074384    0.071918 -0.003425 -0.116781
#
#    MiscFeature  SaleType  SaleCondition
# 0    -0.026884  0.060873        0.04589
# 1    -0.026884  0.060873        0.04589
# 2    -0.026884  0.060873        0.04589
# 3    -0.026884  0.060873       -0.75411
# 4    -0.026884  0.060873        0.04589
#
# [5 rows x 80 columns]

# %%
#%% 
#       =========  #PCA  --- Principal Components ==========

#-------------------------------------------------------------------

#Create a different normalized dataframe for PCA
trPCA = (trNum - trNum.mean()) / trNum.std()

i = np.identity(trPCA.drop('SalePrice', axis=1).shape[1])

pca = PCA(n_components=5, random_state=1010)
pca.fit_transform(trPCA.drop('SalePrice', axis=1).values)

coef = pca.transform(i)
pcp = pd.DataFrame(coef, columns = ['PC-1','PC-2','PC-3','PC-4','PC-5'],
                           index = trPCA.drop('SalePrice', axis=1).columns)

#%% Visualize Principal components

pcp['max'] = pcp.max(axis=1)
pcp['avg'] = pcp.mean(axis=1)
pcp['sum'] = pcp.sum(axis=1)

pcp = pcp.sort_values(by=['sum','avg'], ascending=False)

plt.rcParams['figure.figsize']=(10,20)
sb.heatmap(pcp[['max','sum','avg']], annot=True, annot_kws={"size": 12})

# %%
#%%
#%%
#<> ----  Create new train and test sets based on top principal components
#<><>
#<><><>
#<><><><>

# -- save top components

#conditional top
top = list(pcp[(pcp['sum'] > pcp['sum'].mean())].index)

#sorted list
pclist = list(pcp.index)


# -- Set up training and test sets

pcdata = pd.concat([trNum[pclist[0:78]],trNum['SalePrice']],axis=1)

train, test = train_test_split(pcdata, test_size = .30, random_state = 1010)

# Train outcome and predictors 
y = train.SalePrice
X = train.drop('SalePrice', axis=1)

# Test outcome and predictors
yt = test.SalePrice
Xt = test.drop('SalePrice', axis=1)

# %%
#%%
#               ## ==== Model Training ==== ##
#
#               ## ==== Gradient Boosting Regressor ==== ##

#-----------------------------------------------------------------
#Set model parameters
gbfit = GradientBoostingRegressor(n_estimators=500, loss='ls', random_state=1010)

#Fit model
gbfit.fit(X=X, y=y)

#%% explore GB fit
accuracy = gbfit.score(Xt, yt)
predict = gbfit.predict(Xt)

#%%

# Show results of GBR with all variables

sb.set_style('darkgrid')
plt.rcParams['figure.figsize']=(10,7)
plt.scatter(predict, yt)
plt.suptitle('Gradient Boosting Results')
plt.xlabel('Predicted')
plt.ylabel('Ground Truth')

print('Gradient Boosting Accuracy %s' % '{0:.2%}'.format(accuracy))
# Out:
# Gradient Boosting Accuracy 91.55%

# %%
#%%
# Model feature importances ranking
importances = gbfit.feature_importances_
indices = np.argsort(importances)[::-1]

print('Feature Importances')

for f in range(X.shape[1]):
    print("feature %s (%f)" % (list(X)[f], importances[indices[f]]))

#plot
feat_imp = pd.DataFrame({'Feature':list(X),
                         'Gini Importance':importances[indices]})

plt.rcParams['figure.figsize']=(8,12)
sb.set_style('whitegrid')
ax = sb.barplot(x='Gini Importance', y='Feature', data=feat_imp)
ax.set(xlabel='Gini Importance')
plt.show()    


#_________________________________________________________________________________> 

# End Gradient Boosting .. 
#_________________________________________________________________________________>  
#_________________________________________________________________________________>  
#_________________________________________________________________________________>    
#########
# Out:
# Feature Importances
# feature GrLivArea (0.070536)
# feature TotRmsAbvGrd (0.061763)
# feature MSSubClass (0.046583)
# feature BsmtFinSF1 (0.045752)
# feature HouseStyle (0.043792)
# feature 1stFlrSF (0.043454)
# feature FullBath (0.042657)
# feature LotArea (0.042387)
# feature BsmtFullBath (0.038574)
# feature Fireplaces (0.038106)
# feature 2ndFlrSF (0.032085)
# feature OverallQual (0.031110)
# feature PoolQC (0.030878)
# feature PoolArea (0.027947)
# feature Foundation (0.023687)
# feature FireplaceQu (0.023469)
# feature MasVnrArea (0.020861)
# feature HalfBath (0.019819)
# feature KitchenAbvGr (0.019081)
# feature BedroomAbvGr (0.018352)
# feature TotalBsmtSF (0.014849)
# feature WoodDeckSF (0.013808)
# feature LandSlope (0.013290)
# feature BldgType (0.011580)
# feature OpenPorchSF (0.010659)
# feature RoofMatl (0.010293)
# feature BsmtFinSF2 (0.010185)
# feature RoofStyle (0.009736)
# feature GarageArea (0.008479)
# feature GarageCars (0.008409)
# feature Heating (0.007762)
# feature LowQualFinSF (0.007622)
# feature Electrical (0.007163)
# feature LotFrontage (0.006848)
# feature ScreenPorch (0.006821)
# feature Neighborhood (0.006563)
# feature HeatingQC (0.006045)
# feature MiscFeature (0.005907)
# feature MiscVal (0.005671)
# feature SaleType (0.005453)
# feature BsmtHalfBath (0.005443)
# feature Condition1 (0.005378)
# feature YrsRM (0.004902)
# feature SaleCondition (0.004750)
# feature Utilities (0.004428)
# feature MSZoning (0.004200)
# feature YrsSS (0.004108)
# feature ExterCond (0.004013)
# feature EnclosedPorch (0.003698)
# feature YrsOld (0.003594)
# feature MoSold (0.003569)
# feature 3SsnPorch (0.003560)
# feature MasVnrType (0.003515)
# feature Fence (0.003485)
# feature Condition2 (0.003361)
# feature PavedDrive (0.003346)
# feature LotConfig (0.002694)
# feature Alley (0.002654)
# feature CentralAir (0.002653)
# feature Functional (0.002527)
# feature Street (0.002441)
# feature LandContour (0.002308)
# feature Exterior2nd (0.002298)
# feature Exterior1st (0.002294)
# feature BsmtUnfSF (0.002276)
# feature OverallCond (0.001899)
# feature LotShape (0.001875)
# feature BsmtFinType1 (0.001834)
# feature BsmtCond (0.001642)
# feature KitchenQual (0.001520)
# feature ExterQual (0.001287)
# feature BsmtFinType2 (0.001158)
# feature GarageQual (0.001106)
# feature GarageCond (0.001075)
# feature GarageYrBlt (0.000983)
# feature BsmtQual (0.000093)
# feature BsmtExposure (0.000000)
# feature GarageType (0.000000)

# %%
#%%  
#----------------------------------------------------------------------]\\
    #%%
# -------------- Create Bins for SalesPrice Variable --------------------
# ...
## ... for use with Classification Models


#bins = [0,100000,150000,200000,250000,300000,350000,400000,
##       450000,500000,550000,600000,650000,700000]

# .. need to create labels vector for 'mix type error (string and num)

bins=7
trNum['PriceRange'] = pd.cut(trNum.SalePrice, bins)
trNum_norm['PriceRange'] = pd.cut(trNum.SalePrice, bins)

#%%
#Set up training and test sets for classification

cats = pd.concat([trNum_norm[pclist[0:78]],trNum_norm['PriceRange']],axis=1)

train, test = train_test_split(cats, test_size = .25, random_state=10)

# Train outcome and predictors 
y = train.PriceRange
X = train.drop('PriceRange', axis=1)

# Test outcome and predictors
yt = test.PriceRange
Xt = test.drop('PriceRange', axis=1)

# %% [markdown]
# <hr></h2>**Classification Models**</h2>

# %%
# Classifiers
